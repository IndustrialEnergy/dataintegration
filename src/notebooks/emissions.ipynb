# %%
# Import libraries
import pandas as pd
from pathlib import Path
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import numpy as np
import janitor
from janitor import clean_names

# %%
# Import datasets

# ------- define paths -------
relative_path = Path('../../data/intermediate_data/') # define relative path
absolute_path = relative_path.resolve() # get absolute path


# ------- import data -------
assess_df = pd.read_csv(absolute_path/'iac_assess_tidy.csv') # import IAC assess dataset
ec_emissions_df = pd.read_csv(absolute_path/'emissions_tidy.csv') # import emissions dataset
ec_generation_df = pd.read_csv(absolute_path/'generation.csv') # import electricity generation dataset
recc_integrated_ppi_df = pd.read_csv(absolute_path/'recc_integrated_ppi.csv') # import an integrated recc dataset with adjusted impcost
fuel_emission_factors_df = pd.read_excel(absolute_path/'emission_factors_tidy.xlsx', sheet_name='Sheet1') # import fuel emission factors

# %%
recc_integrated_ppi_df
# Out:
#          superid      id              description  ar_number  appcode    arc2  \
# 0       AM000101  AM0001                      NaN          1      NaN  2.8114
# 1       AM000101  AM0001                      NaN          1      NaN  2.8114
# 2       AM000101  AM0001                      NaN          1      NaN  2.8114
# 3       AM000101  AM0001                      NaN          1      NaN  2.8114
# 4       AM000102  AM0001                      NaN          2      NaN  2.7142
# ...          ...     ...                      ...        ...      ...     ...
# 652595  WV067708  WV0677                      NaN          8      NaN  2.4239
# 652596  WV067709  WV0677  INSULATE BARE EQUIPMENT          9      NaN  2.2511
# 652597  WV067709  WV0677  INSULATE BARE EQUIPMENT          9      NaN  2.2511
# 652598  WV067709  WV0677  INSULATE BARE EQUIPMENT          9      NaN  2.2511
# 652599  WV067709  WV0677  INSULATE BARE EQUIPMENT          9      NaN  2.2511
#
#        impstatus  impcost  impcost_adj source_rank  ...   saved  rebate  \
# 0              N  15000.0          NaN  PSOURCCODE  ...  1828.0       N
# 1              N  15000.0          NaN  SSOURCCODE  ...     NaN       N
# 2              N  15000.0          NaN  TSOURCCODE  ...     NaN       N
# 3              N  15000.0          NaN  QSOURCCODE  ...     NaN       N
# 4              N    189.0          NaN  PSOURCCODE  ...   663.0       N
# ...          ...      ...          ...         ...  ...     ...     ...
# 652595       NaN    540.0          NaN  QSOURCCODE  ...     NaN       N
# 652596       NaN    446.0        446.0  PSOURCCODE  ...   290.0       N
# 652597       NaN    446.0        446.0  SSOURCCODE  ...     NaN       N
# 652598       NaN    446.0        446.0  TSOURCCODE  ...     NaN       N
# 652599       NaN    446.0        446.0  QSOURCCODE  ...     NaN       N
#
#         incremntal    fy ic_capital ic_other   payback  bptool  \
# 0                N  1987        NaN      NaN  8.205689     NaN
# 1                N  1987        NaN      NaN  8.205689     NaN
# 2                N  1987        NaN      NaN  8.205689     NaN
# 3                N  1987        NaN      NaN  8.205689     NaN
# 4                N  1987        NaN      NaN  0.285068     NaN
# ...            ...   ...        ...      ...       ...     ...
# 652595           N  2025      400.0    140.0       NaN     AM+
# 652596           N  2025      330.0    116.0       NaN    SSTS
# 652597           N  2025      330.0    116.0       NaN    SSTS
# 652598           N  2025      330.0    116.0       NaN    SSTS
# 652599           N  2025      330.0    116.0       NaN    SSTS
#
#         reference_year  reference_ppi
# 0                  NaN            NaN
# 1                  NaN            NaN
# 2                  NaN            NaN
# 3                  NaN            NaN
# 4                  NaN            NaN
# ...                ...            ...
# 652595             NaN            NaN
# 652596          2024.0         189.87
# 652597          2024.0         189.87
# 652598          2024.0         189.87
# 652599          2024.0         189.87
#
# [652600 rows x 23 columns]

# %%
ec_emissions_df
# Out:
#        state  year                  producer_type energy_source emission_type  \
# 0         AK  1990               Commercial Cogen   All Sources           CO2
# 1         AK  1990               Commercial Cogen          Coal           CO2
# 2         AK  1990               Commercial Cogen     Petroleum           CO2
# 3         AK  1990           Commercial Non-Cogen   All Sources           CO2
# 4         AK  1990           Commercial Non-Cogen     Petroleum           CO2
# ...      ...   ...                            ...           ...           ...
# 147313    WY  2023  Total Electric Power Industry          Coal           NOx
# 147314    WY  2023  Total Electric Power Industry   Natural Gas           NOx
# 147315    WY  2023  Total Electric Power Industry   Other Gases           NOx
# 147316    WY  2023  Total Electric Power Industry         Other           NOx
# 147317    WY  2023  Total Electric Power Industry     Petroleum           NOx
#
#         amount
# 0       824004
# 1       821929
# 2         2075
# 3            0
# 4            0
# ...        ...
# 147313   22890
# 147314    2258
# 147315    3075
# 147316      42
# 147317      20
#
# [147318 rows x 6 columns]

# %%
fuel_emission_factors_df
# Out:
#    energy_source sourccode  units emission_factor_units  \
# 0    Natural Gas        E2  MMBtu              kg/MMBtu
# 1    Natural Gas        E2  MMBtu              kg/MMBtu
# 2    Natural Gas        E2  MMBtu              kg/MMBtu
# 3          L.P.G        E3  MMBtu              kg/MMBtu
# 4          L.P.G        E3  MMBtu              kg/MMBtu
# 5          L.P.G        E3  MMBtu              kg/MMBtu
# 6    #1 Fuel Oil        E4  MMBtu              kg/MMBtu
# 7    #1 Fuel Oil        E4  MMBtu              kg/MMBtu
# 8    #1 Fuel Oil        E4  MMBtu              kg/MMBtu
# 9    #2 Fuel Oil        E5  MMBtu              kg/MMBtu
# 10   #2 Fuel Oil        E5  MMBtu              kg/MMBtu
# 11   #2 Fuel Oil        E5  MMBtu              kg/MMBtu
# 12   #4 Fuel Oil        E6  MMBtu              kg/MMBtu
# 13   #4 Fuel Oil        E6  MMBtu              kg/MMBtu
# 14   #4 Fuel Oil        E6  MMBtu              kg/MMBtu
# 15   #6 Fuel Oil        E7  MMBtu              kg/MMBtu
# 16   #6 Fuel Oil        E7  MMBtu              kg/MMBtu
# 17   #6 Fuel Oil        E7  MMBtu              kg/MMBtu
# 18          Coal        E8  MMBtu              kg/MMBtu
# 19          Coal        E8  MMBtu              kg/MMBtu
# 20          Coal        E8  MMBtu              kg/MMBtu
# 21          Wood        E9  MMBtu              kg/MMBtu
# 22          Wood        E9  MMBtu              kg/MMBtu
# 23          Wood        E9  MMBtu              kg/MMBtu
# 24  Other Energy       E12  MMBtu              kg/MMBtu
# 25  Other Energy       E12  MMBtu              kg/MMBtu
# 26  Other Energy       E12  MMBtu              kg/MMBtu
#
#                                      fuel_description emission_type  \
# 0   Natural gas is a gas consisting primarily of m...           CO2
# 1   Natural gas is a gas consisting primarily of m...           SO2
# 2   Natural gas is a gas consisting primarily of m...           NOx
# 3   LPG is a mixture of hydrocarbon gases used as ...           CO2
# 4   LPG is a mixture of hydrocarbon gases used as ...           SO2
# 5   LPG is a mixture of hydrocarbon gases used as ...           NOx
# 6   Fuel Oil No. 1 is similar to kerosene and is t...           CO2
# 7   Fuel Oil No. 1 is similar to kerosene and is t...           SO2
# 8   Fuel Oil No. 1 is similar to kerosene and is t...           NOx
# 9   Fuel Oil No. 2 is diesel fuel, which is common...           CO2
# 10  Fuel Oil No. 2 is diesel fuel, which is common...           SO2
# 11  Fuel Oil No. 2 is diesel fuel, which is common...           NOx
# 12  Fuel Oil No. 4 is a blend of distillate and re...           CO2
# 13  Fuel Oil No. 4 is a blend of distillate and re...           SO2
# 14  Fuel Oil No. 4 is a blend of distillate and re...           NOx
# 15  Fuel Oil No. 6 is called residual fuel oil or ...           CO2
# 16  Fuel Oil No. 6 is called residual fuel oil or ...           SO2
# 17  Fuel Oil No. 6 is called residual fuel oil or ...           NOx
# 18  Coal is a fossil fuel which is composed primar...           CO2
# 19  Coal is a fossil fuel which is composed primar...           SO2
# 20  Coal is a fossil fuel which is composed primar...           NOx
# 21  Burning of wood is currently the largest use o...           CO2
# 22  Burning of wood is currently the largest use o...           SO2
# 23  Burning of wood is currently the largest use o...           NOx
# 24  Other Energy includes any energy source, wheth...           CO2
# 25  Other Energy includes any energy source, wheth...           SO2
# 26  Other Energy includes any energy source, wheth...           NOx
#
#     emission_factor
# 0         53.060000
# 1          0.000267
# 2          0.078934
# 3         61.710000
# 4          0.006720
# 5          0.066085
# 6         75.200000
# 7          0.078212
# 8          0.055079
# 9         73.960000
# 10         0.023004
# 11         0.055079
# 12        74.750000
# 13         0.284222
# 14         0.073259
# 15        75.100000
# 16         0.751451
# 17         0.109618
# 18        94.670000
# 19         0.783283
# 20         0.109557
# 21        93.800000
# 22         0.205711
# 23         0.140590
# 24        76.280000
# 25         0.234530
# 26         0.089488

# %%
# remove records that don't have any values for power sources other than primary
recc_integrated_ppi_df = recc_integrated_ppi_df.dropna(subset=['sourccode', 'conserved','sourconsv','saved'], how='all')

# %%
# verify the rows with blank values are not in the dataframe
recc_integrated_ppi_df[recc_integrated_ppi_df['superid']=='AM043901']
# Out:
#         superid      id description  ar_number  appcode   arc2 impstatus  \
# 13300  AM043901  AM0439         NaN          1      1.0  4.132         I
#
#         impcost  impcost_adj source_rank  ...     saved  rebate  incremntal  \
# 13300  435000.0          NaN  PSOURCCODE  ...  910000.0       N           N
#
#          fy ic_capital ic_other   payback  bptool  reference_year  \
# 13300  2003   395000.0  40000.0  0.478022     NaN             NaN
#
#        reference_ppi
# 13300            NaN
#
# [1 rows x 23 columns]

# %%
assess_df.head()
# Out:
#        id center    fy     sic  naics state       sales  employees  \
# 0  AM0001     AM  1987  3671.0    NaN    TX  33900000.0      206.0
# 1  AM0002     AM  1987  2761.0    NaN    TX  25000000.0      156.0
# 2  AM0002     AM  1987  2761.0    NaN    TX  25000000.0      156.0
# 3  AM0003     AM  1987  3494.0    NaN    TX  15000000.0      200.0
# 4  AM0003     AM  1987  3494.0    NaN    TX  15000000.0      200.0
#
#    plant_area                products  produnits  prodlevel  prodhours  \
# 0         NaN  MICRO & MINI COMPUTERS        1.0      310.0     2250.0
# 1         NaN          BUSINESS FORMS        NaN        NaN     2250.0
# 2         NaN          BUSINESS FORMS        NaN        NaN     2250.0
# 3         NaN  SAFETY JOINTS & VALVES        NaN        NaN     2250.0
# 4         NaN  SAFETY JOINTS & VALVES        NaN        NaN     2250.0
#
#    numars source_code  plant_cost  plant_usage
# 0       7          EC    184985.0    2560082.0
# 1       9          EC    267702.0    4867233.0
# 2       9          E2     70657.0      19338.0
# 3       8          EC    129334.0    1723036.0
# 4       8          E2     10146.0       2074.0

# %%
# add Sector and state attributes to recc_integrated_ppi_df from assess_df
# integrate assess_df into 
integrated_ppi_df = pd.merge(recc_integrated_ppi_df, assess_df,
                             left_on=['sourccode', 'id', 'fy'], 
                             right_on=['source_code', 'id','fy'], 
                             how='left')

integrated_ppi_df.drop_duplicates(inplace = True)

# %%
integrated_ppi_df.shape #(247485, 39) (247485, 38)
# Out:
# (247485, 38)

# %%
integrated_ppi_df.columns
# Out:
# Index(['superid', 'id', 'description', 'ar_number', 'appcode', 'arc2',
#        'impstatus', 'impcost', 'impcost_adj', 'source_rank', 'sourccode',
#        'conserved', 'sourconsv', 'saved', 'rebate', 'incremntal', 'fy',
#        'ic_capital', 'ic_other', 'payback', 'bptool', 'reference_year',
#        'reference_ppi', 'center', 'sic', 'naics', 'state', 'sales',
#        'employees', 'plant_area', 'products', 'produnits', 'prodlevel',
#        'prodhours', 'numars', 'source_code', 'plant_cost', 'plant_usage'],
#       dtype='object')

# %%
# check unique power source codes 
integrated_ppi_df['sourccode'].unique()
# Out:
# array(['EC', 'E2', 'R2', 'E3', 'E9', 'E12', 'E4', 'E11', 'W6', 'W1', 'R5',
#        'W5', 'R3', 'W3', 'W4', 'E5', 'W2', 'R1', 'R4', 'ED', 'EF', 'P1',
#        'P2', 'R6', 'P3', 'W0', nan, 'E7', 'E8', 'E6', 'E10'], dtype=object)

# %%
integrated_ppi_df[integrated_ppi_df['superid']=='WV061012']
# Out:
#          superid      id              description  ar_number  appcode    arc2  \
# 246067  WV061012  WV0610  INSULATE BARE EQUIPMENT         12      NaN  2.2511
#
#        impstatus  impcost  impcost_adj source_rank  ... employees  plant_area  \
# 246067         I    488.0       497.76  PSOURCCODE  ...      23.0    116000.0
#
#                       products  produnits prodlevel prodhours  numars  \
# 246067  Processed Coffee Beans        3.0    7690.0    4160.0    12.0
#
#         source_code  plant_cost  plant_usage
# 246067           E2    134406.0      40605.0
#
# [1 rows x 38 columns]

# %%
integrated_ppi_df[integrated_ppi_df['superid']=='AM057403']
# Out:
#        superid      id                                      description  \
# 5837  AM057403  AM0574  UTILIZE HIGHER EFFICIENCY LAMPS AND/OR BALLASTS
# 5838  AM057403  AM0574  UTILIZE HIGHER EFFICIENCY LAMPS AND/OR BALLASTS
# 5839  AM057403  AM0574  UTILIZE HIGHER EFFICIENCY LAMPS AND/OR BALLASTS
#
#       ar_number  appcode    arc2 impstatus  impcost  impcost_adj source_rank  \
# 5837          3      3.0  2.7142         N  52875.0      72967.5  PSOURCCODE
# 5838          3      3.0  2.7142         N  52875.0      72967.5  SSOURCCODE
# 5839          3      3.0  2.7142         N  52875.0      72967.5  TSOURCCODE
#
#       ... employees  plant_area                products  produnits  \
# 5837  ...     150.0    320000.0  Carbonated soft drinks        1.0
# 5838  ...     150.0    320000.0  Carbonated soft drinks        1.0
# 5839  ...       NaN         NaN                     NaN        NaN
#
#        prodlevel prodhours  numars  source_code  plant_cost  plant_usage
# 5837  22685034.0    5773.0    10.0           EC    545600.0   11608476.0
# 5838  22685034.0    5773.0    10.0           ED    212700.0      28944.0
# 5839         NaN       NaN     NaN          NaN         NaN          NaN
#
# [3 rows x 38 columns]

# %% [markdown]
# #### Merge Fuel Emission Factors into the integrated recc table

# %%
# add fuel emission factors to the integrated recc df
integrated_df = pd.merge(integrated_ppi_df, fuel_emission_factors_df[['sourccode','emission_type','emission_factor','emission_factor_units']],
                                  on='sourccode',
                                  how='left')

# %%
integrated_df.head()
# Out:
#     superid      id description  ar_number  appcode    arc2 impstatus  \
# 0  AM000101  AM0001         NaN          1      NaN  2.8114         N
# 1  AM000102  AM0001         NaN          2      NaN  2.7142         N
# 2  AM000103  AM0001         NaN          3      NaN  2.7111         N
# 3  AM000104  AM0001         NaN          4      NaN  2.7447         I
# 4  AM000105  AM0001         NaN          5      NaN  2.7233         N
#
#    impcost  impcost_adj source_rank  ... produnits  prodlevel  prodhours  \
# 0  15000.0          NaN  PSOURCCODE  ...       1.0      310.0     2250.0
# 1    189.0          NaN  PSOURCCODE  ...       1.0      310.0     2250.0
# 2    398.0          NaN  PSOURCCODE  ...       1.0      310.0     2250.0
# 3    354.0          NaN  PSOURCCODE  ...       1.0      310.0     2250.0
# 4     15.0          NaN  PSOURCCODE  ...       1.0      310.0     2250.0
#
#    numars source_code plant_cost  plant_usage  emission_type  emission_factor  \
# 0     7.0          EC   184985.0    2560082.0            NaN              NaN
# 1     7.0          EC   184985.0    2560082.0            NaN              NaN
# 2     7.0          EC   184985.0    2560082.0            NaN              NaN
# 3     7.0          EC   184985.0    2560082.0            NaN              NaN
# 4     7.0          EC   184985.0    2560082.0            NaN              NaN
#
#    emission_factor_units
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
# [5 rows x 41 columns]

# %%
integrated_df[integrated_df['superid'].isin(['WV061012', 'AM057403'])]
# Out:
#          superid      id                                      description  \
# 7081    AM057403  AM0574  UTILIZE HIGHER EFFICIENCY LAMPS AND/OR BALLASTS
# 7082    AM057403  AM0574  UTILIZE HIGHER EFFICIENCY LAMPS AND/OR BALLASTS
# 7083    AM057403  AM0574  UTILIZE HIGHER EFFICIENCY LAMPS AND/OR BALLASTS
# 318739  WV061012  WV0610                          INSULATE BARE EQUIPMENT
# 318740  WV061012  WV0610                          INSULATE BARE EQUIPMENT
# 318741  WV061012  WV0610                          INSULATE BARE EQUIPMENT
#
#         ar_number  appcode    arc2 impstatus  impcost  impcost_adj  \
# 7081            3      3.0  2.7142         N  52875.0     72967.50
# 7082            3      3.0  2.7142         N  52875.0     72967.50
# 7083            3      3.0  2.7142         N  52875.0     72967.50
# 318739         12      NaN  2.2511         I    488.0       497.76
# 318740         12      NaN  2.2511         I    488.0       497.76
# 318741         12      NaN  2.2511         I    488.0       497.76
#
#        source_rank  ... produnits   prodlevel  prodhours  numars source_code  \
# 7081    PSOURCCODE  ...       1.0  22685034.0     5773.0    10.0          EC
# 7082    SSOURCCODE  ...       1.0  22685034.0     5773.0    10.0          ED
# 7083    TSOURCCODE  ...       NaN         NaN        NaN     NaN         NaN
# 318739  PSOURCCODE  ...       3.0      7690.0     4160.0    12.0          E2
# 318740  PSOURCCODE  ...       3.0      7690.0     4160.0    12.0          E2
# 318741  PSOURCCODE  ...       3.0      7690.0     4160.0    12.0          E2
#
#        plant_cost  plant_usage  emission_type  emission_factor  \
# 7081     545600.0   11608476.0            NaN              NaN
# 7082     212700.0      28944.0            NaN              NaN
# 7083          NaN          NaN            NaN              NaN
# 318739   134406.0      40605.0            CO2        53.060000
# 318740   134406.0      40605.0            SO2         0.000267
# 318741   134406.0      40605.0            NOx         0.078934
#
#         emission_factor_units
# 7081                      NaN
# 7082                      NaN
# 7083                      NaN
# 318739               kg/MMBtu
# 318740               kg/MMBtu
# 318741               kg/MMBtu
#
# [6 rows x 41 columns]

# %% [markdown]
# #### Calculate fuel emission factors

# %%
# Calculate fuel emissions avoided
integrated_df['emissions_avoided'] = integrated_df['emission_factor'] * integrated_df['conserved']

# %%
integrated_df.columns
# Out:
# Index(['superid', 'id', 'description', 'ar_number', 'appcode', 'arc2',
#        'impstatus', 'impcost', 'impcost_adj', 'source_rank', 'sourccode',
#        'conserved', 'sourconsv', 'saved', 'rebate', 'incremntal', 'fy',
#        'ic_capital', 'ic_other', 'payback', 'bptool', 'reference_year',
#        'reference_ppi', 'center', 'sic', 'naics', 'state', 'sales',
#        'employees', 'plant_area', 'products', 'produnits', 'prodlevel',
#        'prodhours', 'numars', 'source_code', 'plant_cost', 'plant_usage',
#        'emission_type', 'emission_factor', 'emission_factor_units',
#        'emissions_avoided'],
#       dtype='object')

# %%
integrated_df[integrated_df['superid'].isin(['WV061012', 'AM057403'])]
# Out:
#          superid      id                                      description  \
# 7081    AM057403  AM0574  UTILIZE HIGHER EFFICIENCY LAMPS AND/OR BALLASTS
# 7082    AM057403  AM0574  UTILIZE HIGHER EFFICIENCY LAMPS AND/OR BALLASTS
# 7083    AM057403  AM0574  UTILIZE HIGHER EFFICIENCY LAMPS AND/OR BALLASTS
# 318739  WV061012  WV0610                          INSULATE BARE EQUIPMENT
# 318740  WV061012  WV0610                          INSULATE BARE EQUIPMENT
# 318741  WV061012  WV0610                          INSULATE BARE EQUIPMENT
#
#         ar_number  appcode    arc2 impstatus  impcost  impcost_adj  \
# 7081            3      3.0  2.7142         N  52875.0     72967.50
# 7082            3      3.0  2.7142         N  52875.0     72967.50
# 7083            3      3.0  2.7142         N  52875.0     72967.50
# 318739         12      NaN  2.2511         I    488.0       497.76
# 318740         12      NaN  2.2511         I    488.0       497.76
# 318741         12      NaN  2.2511         I    488.0       497.76
#
#        source_rank  ...   prodlevel  prodhours  numars  source_code  \
# 7081    PSOURCCODE  ...  22685034.0     5773.0    10.0           EC
# 7082    SSOURCCODE  ...  22685034.0     5773.0    10.0           ED
# 7083    TSOURCCODE  ...         NaN        NaN     NaN          NaN
# 318739  PSOURCCODE  ...      7690.0     4160.0    12.0           E2
# 318740  PSOURCCODE  ...      7690.0     4160.0    12.0           E2
# 318741  PSOURCCODE  ...      7690.0     4160.0    12.0           E2
#
#        plant_cost plant_usage  emission_type  emission_factor  \
# 7081     545600.0  11608476.0            NaN              NaN
# 7082     212700.0     28944.0            NaN              NaN
# 7083          NaN         NaN            NaN              NaN
# 318739   134406.0     40605.0            CO2        53.060000
# 318740   134406.0     40605.0            SO2         0.000267
# 318741   134406.0     40605.0            NOx         0.078934
#
#         emission_factor_units  emissions_avoided
# 7081                      NaN                NaN
# 7082                      NaN                NaN
# 7083                      NaN                NaN
# 318739               kg/MMBtu        6579.440000
# 318740               kg/MMBtu           0.033086
# 318741               kg/MMBtu           9.787804
#
# [6 rows x 42 columns]

# %% [markdown]
# # Merge electricity emissions into an integrated recc table

# %%
ec_emissions_df = ec_emissions_df[(ec_emissions_df['producer_type']=='Total Electric Power Industry')& # units = metric ton
                                  (ec_emissions_df['energy_source']=='All Sources')]

ec_generation_df = ec_generation_df[(ec_generation_df['type_of_producer']=='Total Electric Power Industry')&
                                  (ec_generation_df['energy_source']=='Total')]

# %%
ec_emissions_df.columns
# Out:
# Index(['state', 'year', 'producer_type', 'energy_source', 'emission_type',
#        'amount'],
#       dtype='object')

# %%
# calculate emission factors
# Total Emissions/Total Electricity Generated
ec_emission_factors_df = pd.merge(ec_generation_df,ec_emissions_df[['year','state','emission_type','amount']])
ec_emission_factors_df['emission_factor'] = ec_emission_factors_df['amount'] / ec_emission_factors_df['generation_megawatthours_']

# add column emission_factor_units
ec_emission_factors_df['emission_factor_units'] = 'kg/kWh'
ec_emission_factors_df['sourccode'] = 'EC'

# %%
ec_emission_factors_df
# Out:
#       year state               type_of_producer energy_source  \
# 0     1990    AK  Total Electric Power Industry         Total
# 1     1990    AK  Total Electric Power Industry         Total
# 2     1990    AK  Total Electric Power Industry         Total
# 3     1990    AL  Total Electric Power Industry         Total
# 4     1990    AL  Total Electric Power Industry         Total
# ...    ...   ...                            ...           ...
# 5263  2023    WV  Total Electric Power Industry         Total
# 5264  2023    WV  Total Electric Power Industry         Total
# 5265  2023    WY  Total Electric Power Industry         Total
# 5266  2023    WY  Total Electric Power Industry         Total
# 5267  2023    WY  Total Electric Power Industry         Total
#
#       generation_megawatthours_ units emission_type    amount  \
# 0                     5599506.0   MWh           CO2   4208809
# 1                     5599506.0   MWh           SO2     18741
# 2                     5599506.0   MWh           NOx     12562
# 3                    79652133.0   MWh           CO2  52936063
# 4                    79652133.0   MWh           SO2    505530
# ...                         ...   ...           ...       ...
# 5263                 52286784.0   MWh           SO2     35530
# 5264                 52286784.0   MWh           NOx     25505
# 5265                 43181420.0   MWh           CO2  36580219
# 5266                 43181420.0   MWh           SO2     21963
# 5267                 43181420.0   MWh           NOx     28285
#
#       emission_factor emission_factor_units sourccode
# 0            0.751639                kg/kWh        EC
# 1            0.003347                kg/kWh        EC
# 2            0.002243                kg/kWh        EC
# 3            0.664591                kg/kWh        EC
# 4            0.006347                kg/kWh        EC
# ...               ...                   ...       ...
# 5263         0.000680                kg/kWh        EC
# 5264         0.000488                kg/kWh        EC
# 5265         0.847129                kg/kWh        EC
# 5266         0.000509                kg/kWh        EC
# 5267         0.000655                kg/kWh        EC
#
# [5268 rows x 11 columns]

# %%
integrated_df.columns
# Out:
# Index(['superid', 'id', 'description', 'ar_number', 'appcode', 'arc2',
#        'impstatus', 'impcost', 'impcost_adj', 'source_rank', 'sourccode',
#        'conserved', 'sourconsv', 'saved', 'rebate', 'incremntal', 'fy',
#        'ic_capital', 'ic_other', 'payback', 'bptool', 'reference_year',
#        'reference_ppi', 'center', 'sic', 'naics', 'state', 'sales',
#        'employees', 'plant_area', 'products', 'produnits', 'prodlevel',
#        'prodhours', 'numars', 'source_code', 'plant_cost', 'plant_usage',
#        'emission_type', 'emission_factor', 'emission_factor_units',
#        'emissions_avoided'],
#       dtype='object')

# %%
ec_emission_factors_df.columns
# Out:
# Index(['year', 'state', 'type_of_producer', 'energy_source',
#        'generation_megawatthours_', 'units', 'emission_type', 'amount',
#        'emission_factor', 'emission_factor_units', 'sourccode'],
#       dtype='object')

# %%
integrated_df.columns
# Out:
# Index(['superid', 'id', 'description', 'ar_number', 'appcode', 'arc2',
#        'impstatus', 'impcost', 'impcost_adj', 'source_rank', 'sourccode',
#        'conserved', 'sourconsv', 'saved', 'rebate', 'incremntal', 'fy',
#        'ic_capital', 'ic_other', 'payback', 'bptool', 'reference_year',
#        'reference_ppi', 'center', 'sic', 'naics', 'state', 'sales',
#        'employees', 'plant_area', 'products', 'produnits', 'prodlevel',
#        'prodhours', 'numars', 'source_code', 'plant_cost', 'plant_usage',
#        'emission_type', 'emission_factor', 'emission_factor_units',
#        'emissions_avoided'],
#       dtype='object')

# %%
ec_emission_factors_df.columns
# Out:
# Index(['year', 'state', 'type_of_producer', 'energy_source',
#        'generation_megawatthours_', 'units', 'emission_type', 'amount',
#        'emission_factor', 'emission_factor_units', 'sourccode'],
#       dtype='object')

# %%
# combine ec_emission_factors_df with the integrated recc table
integrated_df = pd.merge(integrated_df, ec_emission_factors_df[['state','year','emission_type','emission_factor','emission_factor_units','sourccode']],
                         left_on=['fy','state','sourccode'],
                         right_on=['year','state','sourccode'],
                         how='left')

# merge overlapping columns
integrated_df['emission_type'] = integrated_df['emission_type_x'].combine_first(integrated_df['emission_type_y'])
integrated_df['emission_factor_units'] = integrated_df['emission_factor_units_x'].combine_first(integrated_df['emission_factor_units_y'])
integrated_df['emission_factor'] = integrated_df['emission_factor_x'].combine_first(integrated_df['emission_factor_y'])

# drop the old duplicate columns
integrated_df.drop(columns=['emission_type_x', 'emission_type_y', 'emission_factor_units_x', 'emission_factor_units_y', 'year','emission_factor_x','emission_factor_y'], 
                   inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 2
#       1 # combine ec_emission_factors_df with the integrated recc table
# ----> 2 integrated_df = pd.merge(integrated_df, ec_emission_factors_df[['state','year','fy','emission_type','emission_factor','emission_factor_units','sourccode']],
#       3                          left_on=['fy','state','sourccode'],
#       4                          right_on=['year','state','sourccode'],
#       5                          how='left')
#       7 # merge overlapping columns
#       8 integrated_df['emission_type'] = integrated_df['emission_type_x'].combine_first(integrated_df['emission_type_y'])
#
# File ~/opt/anaconda3/envs/eds220-env/lib/python3.11/site-packages/pandas/core/frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
#    3902 if getattr(indexer, "dtype", None) == bool:
#
# File ~/opt/anaconda3/envs/eds220-env/lib/python3.11/site-packages/pandas/core/indexes/base.py:6114, in Index._get_indexer_strict(self, key, axis_name)
#    6111 else:
#    6112     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6114 self._raise_if_missing(keyarr, indexer, axis_name)
#    6116 keyarr = self.take(indexer)
#    6117 if isinstance(key, Index):
#    6118     # GH 42790 - Preserve name from an Index
#
# File ~/opt/anaconda3/envs/eds220-env/lib/python3.11/site-packages/pandas/core/indexes/base.py:6178, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6175     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6177 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6178 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['fy'] not in index"

# %%
integrated_df[integrated_df['superid'].isin(['WV061012', 'AM057403'])]

# %%
integrated_df.loc[integrated_df['sourccode'] == 'EC', 'emissions_avoided'] = (
    integrated_df['emission_factor'] * integrated_df['conserved']
)
integrated_df.loc[integrated_df['sourccode'] == 'EC', 'emissions_avoided'] = (
    integrated_df['emission_factor'] * integrated_df['conserved']
)

# %%
integrated_df[integrated_df['id'].isin(['SF0532', 'OR0712', 'MI0415','IC0115'])]

# %%
integrated_df[integrated_df['superid'].isin(['WV061012', 'AM057403','MI041503','SF053206','SF053207','MI041503','IC011501'])]

# %% [markdown]
# ## Generate a final integrated dataset

# %%
# save integrated dataframe
integrated_df.to_csv("../../data/intermediate_data/iac_integrated.csv", index=False)
