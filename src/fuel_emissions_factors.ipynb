# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
from pathlib import Path
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import janitor
from janitor import clean_names

# %% [markdown]
# ### Import Data

# %%
# ------- define paths -------
# define relative paths
relative_path_raw = Path('../data/raw_data/')

# get absolute paths
absolute_path_raw = relative_path.resolve()
print(absolute_path)

# declare file names
filename_fuel_factors = "Fuel_Emission_Factors.xlsx"
filename_assess_recc = "assess_recc_ppi_emissions.csv"

# ------- import data -------

# import Fuel Emissions Factors database
fuel_emissions_df = pd.read_excel(absolute_path_raw/filename_fuel_factors, sheet_name='Fuel_Emission_Factors_Clean')

# import assess_recc_ppi_emissions database
fuel_assess_recc = pd.read_csv(absolute_path_raw/filename_assess_recc)
# Out:
# /Users/nmoraes/Capstone/industrialenergy_datainterface/data/raw_data
# /tmp/ipykernel_303378/1058186733.py:19: DtypeWarning: Columns (31) have mixed types. Specify dtype option on import or set low_memory=False.
#   fuel_assess_recc = pd.read_csv(absolute_path_raw/filename_assess_recc)

# %% [markdown]
# ### Tidy Dataframe

# %%
fuel_emissions_df.head(3)
# Out:
#       fuel_type iac_fuel_code fuel_units  \
# 0   Natural Gas            E2      MMBtu
# 1         L.P.G            E3      MMBtu
# 2  #1 Fuel Oil             E4      MMBtu
#
#      Fuel mapping per Eric Masanet's table    CO2  \
# 0  Natural Gas (pipeline weighted average)  53.06
# 1                         LPG (energy use)  61.71
# 2                                 Kerosene  75.20
#
#    AP - 42 source (link calculations)       SO2       NOx  \
# 0              Natural gas combustion  0.000267  0.078934
# 1  Liquified petroleum gas combustion  0.006720  0.066085
# 2                 Fuel Oil Combustion  0.078212  0.055079
#
#   emission_factor_units                                   fuel_description
# 0              kg/MMBtu  Natural gas is a gas consisting primarily of m...
# 1              kg/MMBtu  LPG is a mixture of hydrocarbon gases used as ...
# 2              kg/MMBtu  Fuel Oil No. 1 is similar to kerosene and is t...

# %%
# print df column names
fuel_emissions_df.columns
# Out:
# Index(['fuel_type', 'iac_fuel_code', 'fuel_units',
#        'Fuel mapping per Eric Masanet's table', 'CO2',
#        'AP - 42 source (link calculations)', 'SO2', 'NOx',
#        'emission_factor_units', 'fuel_description'],
#       dtype='object')

# %%
# Select relevant columns
clean_fuel_emissions_df = fuel_emissions_df[['fuel_type', 'iac_fuel_code', 'fuel_units', 
                                             'CO2', 'SO2', 'NOx',
                                             'emission_factor_units', 'fuel_description']]

# %%
clean_fuel_emissions_df.head(2)
# Out:
#      fuel_type iac_fuel_code fuel_units    CO2       SO2       NOx  \
# 0  Natural Gas            E2      MMBtu  53.06  0.000267  0.078934
# 1        L.P.G            E3      MMBtu  61.71  0.006720  0.066085
#
#   emission_factor_units                                   fuel_description
# 0              kg/MMBtu  Natural gas is a gas consisting primarily of m...
# 1              kg/MMBtu  LPG is a mixture of hydrocarbon gases used as ...

# %%
# transform columns to match assess_recc table
rename_emissions_df = clean_fuel_emissions_df.copy()

# %%
rename_emissions_df.rename(columns={'fuel_type': 'energy_source', 
                                        'iac_fuel_code': 'sourccode',
                                        'fuel_units': 'units',
                                       'emission_factor_units': 'unit'}, inplace=True)

# %%
# View rename_emissions_df
rename_emissions_df.head(2)
# Out:
#   energy_source sourccode  units    CO2       SO2       NOx      unit  \
# 0   Natural Gas        E2  MMBtu  53.06  0.000267  0.078934  kg/MMBtu
# 1         L.P.G        E3  MMBtu  61.71  0.006720  0.066085  kg/MMBtu
#
#                                     fuel_description
# 0  Natural gas is a gas consisting primarily of m...
# 1  LPG is a mixture of hydrocarbon gases used as ...

# %%
# Place CO2, SO2, NOx on top of each other

melted_df = rename_emissions_df.melt(
    id_vars=['energy_source', 'sourccode', 'units', 'unit', 'fuel_description'],
                    value_vars=['CO2', 'SO2', 'NOx'],
                    var_name='emission_type',
                    value_name='emission_factor')

# %%
melted_df.head(15)
# Out:
#     energy_source sourccode  units      unit  \
# 0     Natural Gas        E2  MMBtu  kg/MMBtu
# 1           L.P.G        E3  MMBtu  kg/MMBtu
# 2    #1 Fuel Oil         E4  MMBtu  kg/MMBtu
# 3    #2 Fuel Oil         E5  MMBtu  kg/MMBtu
# 4    #4 Fuel Oil         E6  MMBtu  kg/MMBtu
# 5    #6 Fuel Oil         E7  MMBtu  kg/MMBtu
# 6           Coal         E8  MMBtu  kg/MMBtu
# 7           Wood         E9  MMBtu  kg/MMBtu
# 8          Paper        E10  MMBtu  kg/MMBtu
# 9      Other Gas        E11  MMBtu  kg/MMBtu
# 10  Other Energy        E12  MMBtu  kg/MMBtu
# 11    Natural Gas        E2  MMBtu  kg/MMBtu
# 12          L.P.G        E3  MMBtu  kg/MMBtu
# 13   #1 Fuel Oil         E4  MMBtu  kg/MMBtu
# 14   #2 Fuel Oil         E5  MMBtu  kg/MMBtu
#
#                                      fuel_description emission_type  \
# 0   Natural gas is a gas consisting primarily of m...           CO2
# 1   LPG is a mixture of hydrocarbon gases used as ...           CO2
# 2   Fuel Oil No. 1 is similar to kerosene and is t...           CO2
# 3   Fuel Oil No. 2 is diesel fuel, which is common...           CO2
# 4   Fuel Oil No. 4 is a blend of distillate and re...           CO2
# 5   Fuel Oil No. 6 is called residual fuel oil or ...           CO2
# 6   Coal is a fossil fuel which is composed primar...           CO2
# 7   Burning of wood is currently the largest use o...           CO2
# 8   Paper is a thin material mainly used for writi...           CO2
# 9   Other Gas includes the use of gaseous fuels as...           CO2
# 10  Other Energy includes any energy source, wheth...           CO2
# 11  Natural gas is a gas consisting primarily of m...           SO2
# 12  LPG is a mixture of hydrocarbon gases used as ...           SO2
# 13  Fuel Oil No. 1 is similar to kerosene and is t...           SO2
# 14  Fuel Oil No. 2 is diesel fuel, which is common...           SO2
#
#     emission_factor
# 0         53.060000
# 1         61.710000
# 2         75.200000
# 3         73.960000
# 4         74.753333
# 5         75.100000
# 6         94.670000
# 7         93.800000
# 8         93.800000
# 9         66.720000
# 10        76.277333
# 11         0.000267
# 12         0.006720
# 13         0.078212
# 14         0.023004

# %% [markdown]
# ### Integrate Assess_Recc Table

# %%
# View all columns
pd.set_option('display.max_columns', None)

# %%
# View assess_recc
fuel_assess_recc.head(5)
# Out:
#   state  year               type_of_producer energy_source  \
# 0    TX  1990  Total Electric Power Industry         Total
# 1    TX  1990  Total Electric Power Industry         Total
# 2    TX  1990  Total Electric Power Industry         Total
# 3    TX  1990  Total Electric Power Industry         Total
# 4    TX  1990  Total Electric Power Industry         Total
#
#    generation_megawatthours units emission_type       amount  emission_factor  \
# 0               281559635.0   MWh           CO2  213056168.0         0.756700
# 1               281559635.0   MWh           SO2     568924.0         0.002021
# 2               281559635.0   MWh           NOx     662759.0         0.002354
# 3               281559635.0   MWh           CO2  213056168.0         0.756700
# 4               281559635.0   MWh           SO2     568924.0         0.002021
#
#      unit      id   superid center  ar_number  appcode    arc2 impstatus  \
# 0  kg/kWh  AM0076  AM007601     AM          1      NaN  2.3212         I
# 1  kg/kWh  AM0076  AM007601     AM          1      NaN  2.3212         I
# 2  kg/kWh  AM0076  AM007601     AM          1      NaN  2.3212         I
# 3  kg/kWh  AM0076  AM007601     AM          1      NaN  2.3212         I
# 4  kg/kWh  AM0076  AM007601     AM          1      NaN  2.3212         I
#
#    impcost  ref_year_impcost source_rank sourccode  conserved  \
# 0  64000.0           64000.0  PSOURCCODE        EC        NaN
# 1  64000.0           64000.0  PSOURCCODE        EC        NaN
# 2  64000.0           64000.0  PSOURCCODE        EC        NaN
# 3  64000.0           64000.0  SSOURCCODE       NaN        NaN
# 4  64000.0           64000.0  SSOURCCODE       NaN        NaN
#
#    conserved_emissions   u  sourconsv    saved rebate incremntal  ic_capital  \
# 0                  NaN  kg        NaN  23000.0      N          N         NaN
# 1                  NaN  kg        NaN  23000.0      N          N         NaN
# 2                  NaN  kg        NaN  23000.0      N          N         NaN
# 3                  NaN  kg        NaN      NaN      N          N         NaN
# 4                  NaN  kg        NaN      NaN      N          N         NaN
#
#    ic_other   payback bptool     sic  naics       sales  employees  \
# 0       NaN  2.782609    NaN  3479.0    NaN  10000000.0       80.0
# 1       NaN  2.782609    NaN  3479.0    NaN  10000000.0       80.0
# 2       NaN  2.782609    NaN  3479.0    NaN  10000000.0       80.0
# 3       NaN  2.782609    NaN  3479.0    NaN  10000000.0       80.0
# 4       NaN  2.782609    NaN  3479.0    NaN  10000000.0       80.0
#
#    plant_area     products  produnits  prodlevel  prodhours  numars  \
# 0         NaN  PIPECOATING        6.0     9038.0     2400.0     5.0
# 1         NaN  PIPECOATING        6.0     9038.0     2400.0     5.0
# 2         NaN  PIPECOATING        6.0     9038.0     2400.0     5.0
# 3         NaN  PIPECOATING        6.0     9038.0     2400.0     5.0
# 4         NaN  PIPECOATING        6.0     9038.0     2400.0     5.0
#
#    ec_plant_cost  ec_plant_usage  ec_emissions u.1  ed_plant_cost  \
# 0       269266.0       3456917.0  2.615849e+06  kg            NaN
# 1       269266.0       3456917.0  6.985103e+03  kg            NaN
# 2       269266.0       3456917.0  8.137185e+03  kg            NaN
# 3       269266.0       3456917.0  2.615849e+06  kg            NaN
# 4       269266.0       3456917.0  6.985103e+03  kg            NaN
#
#    ed_plant_usage  ef_plant_cost  e2_plant_cost  e2_plant_usage  \
# 0             NaN            NaN        29923.0          8238.0
# 1             NaN            NaN        29923.0          8238.0
# 2             NaN            NaN        29923.0          8238.0
# 3             NaN            NaN        29923.0          8238.0
# 4             NaN            NaN        29923.0          8238.0
#
#    e3_plant_cost  e3_plant_usage  e4_plant_cost  e4_plant_usage  \
# 0            NaN             NaN            NaN             NaN
# 1            NaN             NaN            NaN             NaN
# 2            NaN             NaN            NaN             NaN
# 3            NaN             NaN            NaN             NaN
# 4            NaN             NaN            NaN             NaN
#
#    e5_plant_cost  e5_plant_usage  e6_plant_cost  e6_plant_usage  \
# 0            NaN             NaN            NaN             NaN
# 1            NaN             NaN            NaN             NaN
# 2            NaN             NaN            NaN             NaN
# 3            NaN             NaN            NaN             NaN
# 4            NaN             NaN            NaN             NaN
#
#    e7_plant_cost  e7_plant_usage  e8_plant_cost  e8_plant_usage  \
# 0            NaN             NaN            NaN             NaN
# 1            NaN             NaN            NaN             NaN
# 2            NaN             NaN            NaN             NaN
# 3            NaN             NaN            NaN             NaN
# 4            NaN             NaN            NaN             NaN
#
#    e9_plant_cost  e9_plant_usage  e10_plant_cost  e10_plant_usage  \
# 0            NaN             NaN             NaN              NaN
# 1            NaN             NaN             NaN              NaN
# 2            NaN             NaN             NaN              NaN
# 3            NaN             NaN             NaN              NaN
# 4            NaN             NaN             NaN              NaN
#
#    e11_plant_cost  e11_plant_usage  e12_plant_cost  e12_plant_usage  \
# 0             NaN              NaN             NaN              NaN
# 1             NaN              NaN             NaN              NaN
# 2             NaN              NaN             NaN              NaN
# 3             NaN              NaN             NaN              NaN
# 4             NaN              NaN             NaN              NaN
#
#    w0_plant_cost  w0_plant_usage  w1_plant_cost  w1_plant_usage  \
# 0            NaN             NaN            NaN             NaN
# 1            NaN             NaN            NaN             NaN
# 2            NaN             NaN            NaN             NaN
# 3            NaN             NaN            NaN             NaN
# 4            NaN             NaN            NaN             NaN
#
#    w2_plant_cost  w2_plant_usage  w3_plant_cost  w3_plant_usage  \
# 0            NaN             NaN            NaN             NaN
# 1            NaN             NaN            NaN             NaN
# 2            NaN             NaN            NaN             NaN
# 3            NaN             NaN            NaN             NaN
# 4            NaN             NaN            NaN             NaN
#
#    w4_plant_cost  w4_plant_usage  w5_plant_cost  w5_plant_usage  \
# 0            NaN             NaN            NaN             NaN
# 1            NaN             NaN            NaN             NaN
# 2            NaN             NaN            NaN             NaN
# 3            NaN             NaN            NaN             NaN
# 4            NaN             NaN            NaN             NaN
#
#    w6_plant_cost  w6_plant_usage
# 0            NaN             NaN
# 1            NaN             NaN
# 2            NaN             NaN
# 3            NaN             NaN
# 4            NaN             NaN

# %%
fuel_assess_recc.columns
# Out:
# Index(['state', 'year', 'type_of_producer', 'energy_source',
#        'generation_megawatthours', 'units', 'emission_type', 'amount',
#        'emission_factor', 'unit', 'id', 'superid', 'center', 'ar_number',
#        'appcode', 'arc2', 'impstatus', 'impcost', 'ref_year_impcost',
#        'source_rank', 'sourccode', 'conserved', 'conserved_emissions', 'u',
#        'sourconsv', 'saved', 'rebate', 'incremntal', 'ic_capital', 'ic_other',
#        'payback', 'bptool', 'sic', 'naics', 'sales', 'employees', 'plant_area',
#        'products', 'produnits', 'prodlevel', 'prodhours', 'numars',
#        'ec_plant_cost', 'ec_plant_usage', 'ec_emissions', 'u.1',
#        'ed_plant_cost', 'ed_plant_usage', 'ef_plant_cost', 'e2_plant_cost',
#        'e2_plant_usage', 'e3_plant_cost', 'e3_plant_usage', 'e4_plant_cost',
#        'e4_plant_usage', 'e5_plant_cost', 'e5_plant_usage', 'e6_plant_cost',
#        'e6_plant_usage', 'e7_plant_cost', 'e7_plant_usage', 'e8_plant_cost',
#        'e8_plant_usage', 'e9_plant_cost', 'e9_plant_usage', 'e10_plant_cost',
#        'e10_plant_usage', 'e11_plant_cost', 'e11_plant_usage',
#        'e12_plant_cost', 'e12_plant_usage', 'w0_plant_cost', 'w0_plant_usage',
#        'w1_plant_cost', 'w1_plant_usage', 'w2_plant_cost', 'w2_plant_usage',
#        'w3_plant_cost', 'w3_plant_usage', 'w4_plant_cost', 'w4_plant_usage',
#        'w5_plant_cost', 'w5_plant_usage', 'w6_plant_cost', 'w6_plant_usage'],
#       dtype='object')

# %%
# Use 'merge' function
fuel_assess_recc_merge = pd.merge(
    fuel_assess_recc, 
    melted_df,
    on=['energy_source', 'sourccode', 'units', 'unit', 'emission_type', 'emission_fact'],
    how='outer'  # Use 'outer' to keep all rows from both dataframes
)

# %%
fuel_assess_recc_merge.head()
# Out:
#   state  year type_of_producer energy_source  generation_megawatthours  units  \
# 0   NaN   NaN              NaN  #1 Fuel Oil                        NaN  MMBtu
# 1   NaN   NaN              NaN  #1 Fuel Oil                        NaN  MMBtu
# 2   NaN   NaN              NaN  #1 Fuel Oil                        NaN  MMBtu
# 3   NaN   NaN              NaN  #2 Fuel Oil                        NaN  MMBtu
# 4   NaN   NaN              NaN  #2 Fuel Oil                        NaN  MMBtu
#
#   emission_type  amount  emission_factor      unit   id superid center  \
# 0           CO2     NaN        75.200000  kg/MMBtu  NaN     NaN    NaN
# 1           NOx     NaN         0.055079  kg/MMBtu  NaN     NaN    NaN
# 2           SO2     NaN         0.078212  kg/MMBtu  NaN     NaN    NaN
# 3           CO2     NaN        73.960000  kg/MMBtu  NaN     NaN    NaN
# 4           NOx     NaN         0.055079  kg/MMBtu  NaN     NaN    NaN
#
#    ar_number  appcode  arc2 impstatus  impcost  ref_year_impcost source_rank  \
# 0        NaN      NaN   NaN       NaN      NaN               NaN         NaN
# 1        NaN      NaN   NaN       NaN      NaN               NaN         NaN
# 2        NaN      NaN   NaN       NaN      NaN               NaN         NaN
# 3        NaN      NaN   NaN       NaN      NaN               NaN         NaN
# 4        NaN      NaN   NaN       NaN      NaN               NaN         NaN
#
#   sourccode  conserved  conserved_emissions    u  sourconsv  saved rebate  \
# 0        E4        NaN                  NaN  NaN        NaN    NaN    NaN
# 1        E4        NaN                  NaN  NaN        NaN    NaN    NaN
# 2        E4        NaN                  NaN  NaN        NaN    NaN    NaN
# 3        E5        NaN                  NaN  NaN        NaN    NaN    NaN
# 4        E5        NaN                  NaN  NaN        NaN    NaN    NaN
#
#   incremntal  ic_capital  ic_other  payback bptool  sic  naics  sales  \
# 0        NaN         NaN       NaN      NaN    NaN  NaN    NaN    NaN
# 1        NaN         NaN       NaN      NaN    NaN  NaN    NaN    NaN
# 2        NaN         NaN       NaN      NaN    NaN  NaN    NaN    NaN
# 3        NaN         NaN       NaN      NaN    NaN  NaN    NaN    NaN
# 4        NaN         NaN       NaN      NaN    NaN  NaN    NaN    NaN
#
#    employees  plant_area products  produnits  prodlevel  prodhours  numars  \
# 0        NaN         NaN      NaN        NaN        NaN        NaN     NaN
# 1        NaN         NaN      NaN        NaN        NaN        NaN     NaN
# 2        NaN         NaN      NaN        NaN        NaN        NaN     NaN
# 3        NaN         NaN      NaN        NaN        NaN        NaN     NaN
# 4        NaN         NaN      NaN        NaN        NaN        NaN     NaN
#
#    ec_plant_cost  ec_plant_usage  ec_emissions  u.1  ed_plant_cost  \
# 0            NaN             NaN           NaN  NaN            NaN
# 1            NaN             NaN           NaN  NaN            NaN
# 2            NaN             NaN           NaN  NaN            NaN
# 3            NaN             NaN           NaN  NaN            NaN
# 4            NaN             NaN           NaN  NaN            NaN
#
#    ed_plant_usage  ef_plant_cost  e2_plant_cost  e2_plant_usage  \
# 0             NaN            NaN            NaN             NaN
# 1             NaN            NaN            NaN             NaN
# 2             NaN            NaN            NaN             NaN
# 3             NaN            NaN            NaN             NaN
# 4             NaN            NaN            NaN             NaN
#
#    e3_plant_cost  e3_plant_usage  e4_plant_cost  e4_plant_usage  \
# 0            NaN             NaN            NaN             NaN
# 1            NaN             NaN            NaN             NaN
# 2            NaN             NaN            NaN             NaN
# 3            NaN             NaN            NaN             NaN
# 4            NaN             NaN            NaN             NaN
#
#    e5_plant_cost  e5_plant_usage  e6_plant_cost  e6_plant_usage  \
# 0            NaN             NaN            NaN             NaN
# 1            NaN             NaN            NaN             NaN
# 2            NaN             NaN            NaN             NaN
# 3            NaN             NaN            NaN             NaN
# 4            NaN             NaN            NaN             NaN
#
#    e7_plant_cost  e7_plant_usage  e8_plant_cost  e8_plant_usage  \
# 0            NaN             NaN            NaN             NaN
# 1            NaN             NaN            NaN             NaN
# 2            NaN             NaN            NaN             NaN
# 3            NaN             NaN            NaN             NaN
# 4            NaN             NaN            NaN             NaN
#
#    e9_plant_cost  e9_plant_usage  e10_plant_cost  e10_plant_usage  \
# 0            NaN             NaN             NaN              NaN
# 1            NaN             NaN             NaN              NaN
# 2            NaN             NaN             NaN              NaN
# 3            NaN             NaN             NaN              NaN
# 4            NaN             NaN             NaN              NaN
#
#    e11_plant_cost  e11_plant_usage  e12_plant_cost  e12_plant_usage  \
# 0             NaN              NaN             NaN              NaN
# 1             NaN              NaN             NaN              NaN
# 2             NaN              NaN             NaN              NaN
# 3             NaN              NaN             NaN              NaN
# 4             NaN              NaN             NaN              NaN
#
#    w0_plant_cost  w0_plant_usage  w1_plant_cost  w1_plant_usage  \
# 0            NaN             NaN            NaN             NaN
# 1            NaN             NaN            NaN             NaN
# 2            NaN             NaN            NaN             NaN
# 3            NaN             NaN            NaN             NaN
# 4            NaN             NaN            NaN             NaN
#
#    w2_plant_cost  w2_plant_usage  w3_plant_cost  w3_plant_usage  \
# 0            NaN             NaN            NaN             NaN
# 1            NaN             NaN            NaN             NaN
# 2            NaN             NaN            NaN             NaN
# 3            NaN             NaN            NaN             NaN
# 4            NaN             NaN            NaN             NaN
#
#    w4_plant_cost  w4_plant_usage  w5_plant_cost  w5_plant_usage  \
# 0            NaN             NaN            NaN             NaN
# 1            NaN             NaN            NaN             NaN
# 2            NaN             NaN            NaN             NaN
# 3            NaN             NaN            NaN             NaN
# 4            NaN             NaN            NaN             NaN
#
#    w6_plant_cost  w6_plant_usage  \
# 0            NaN             NaN
# 1            NaN             NaN
# 2            NaN             NaN
# 3            NaN             NaN
# 4            NaN             NaN
#
#                                     fuel_description
# 0  Fuel Oil No. 1 is similar to kerosene and is t...
# 1  Fuel Oil No. 1 is similar to kerosene and is t...
# 2  Fuel Oil No. 1 is similar to kerosene and is t...
# 3  Fuel Oil No. 2 is diesel fuel, which is common...
# 4  Fuel Oil No. 2 is diesel fuel, which is common...

# %%
fuel_assess_recc_merge[fuel_assess_recc_merge['state'] == 'TX']
# Out:
#         state    year               type_of_producer energy_source  \
# 154        TX  2002.0  Total Electric Power Industry         Total
# 155        TX  2002.0  Total Electric Power Industry         Total
# 159        TX  1993.0  Total Electric Power Industry         Total
# 270        TX  2002.0  Total Electric Power Industry         Total
# 271        TX  2002.0  Total Electric Power Industry         Total
# ...       ...     ...                            ...           ...
# 1569087    TX  1997.0  Total Electric Power Industry         Total
# 1569088    TX  1997.0  Total Electric Power Industry         Total
# 1569089    TX  1997.0  Total Electric Power Industry         Total
# 1569090    TX  1997.0  Total Electric Power Industry         Total
# 1569091    TX  1997.0  Total Electric Power Industry         Total
#
#          generation_megawatthours units emission_type       amount  \
# 154                   385628542.0   MWh           CO2  258398088.0
# 155                   385628542.0   MWh           CO2  258398088.0
# 159                   299688715.0   MWh           CO2  227087867.0
# 270                   385628542.0   MWh           NOx     332612.0
# 271                   385628542.0   MWh           NOx     332612.0
# ...                           ...   ...           ...          ...
# 1569087               336319510.0   MWh           SO2     777211.0
# 1569088               336319510.0   MWh           SO2     777211.0
# 1569089               336319510.0   MWh           SO2     777211.0
# 1569090               336319510.0   MWh           SO2     777211.0
# 1569091               336319510.0   MWh           SO2     777211.0
#
#          emission_factor    unit      id   superid center  ar_number  appcode  \
# 154             0.670070  kg/kWh  AM0423  AM042303     AM        3.0      2.0
# 155             0.670070  kg/kWh  AM0423  AM042307     AM        7.0      2.0
# 159             0.757746  kg/kWh  AM0173  AM017304     AM        4.0      2.0
# 270             0.000863  kg/kWh  AM0423  AM042303     AM        3.0      2.0
# 271             0.000863  kg/kWh  AM0423  AM042307     AM        7.0      2.0
# ...                  ...     ...     ...       ...    ...        ...      ...
# 1569087         0.002311  kg/kWh  KG0100  KG010003     KG        3.0      4.0
# 1569088         0.002311  kg/kWh  KG0100  KG010003     KG        3.0      4.0
# 1569089         0.002311  kg/kWh  KG0100  KG010004     KG        4.0      4.0
# 1569090         0.002311  kg/kWh  KG0100  KG010004     KG        4.0      4.0
# 1569091         0.002311  kg/kWh  KG0100  KG010004     KG        4.0      4.0
#
#            arc2 impstatus   impcost  ref_year_impcost source_rank sourccode  \
# 154      2.4323         I   25000.0           25000.0  PSOURCCODE       E11
# 155      4.6320         N  249000.0               NaN  PSOURCCODE       E11
# 159      2.2135         I     600.0             600.0  PSOURCCODE       E11
# 270      2.4323         I   25000.0           25000.0  PSOURCCODE       E11
# 271      4.6320         N  249000.0               NaN  PSOURCCODE       E11
# ...         ...       ...       ...               ...         ...       ...
# 1569087  3.5315         K       NaN               NaN  TSOURCCODE       NaN
# 1569088  3.5315         K       NaN               NaN  QSOURCCODE       NaN
# 1569089  3.5315         K       NaN               NaN  SSOURCCODE       NaN
# 1569090  3.5315         K       NaN               NaN  TSOURCCODE       NaN
# 1569091  3.5315         K       NaN               NaN  QSOURCCODE       NaN
#
#          conserved  conserved_emissions   u  sourconsv      saved rebate  \
# 154       495000.0                  NaN  kg        NaN  1311800.0      N
# 155        50400.0                  NaN  kg        NaN   133600.0      N
# 159         1520.0                  NaN  kg        NaN     3670.0      N
# 270       495000.0                  NaN  kg        NaN  1311800.0      N
# 271        50400.0                  NaN  kg        NaN   133600.0      N
# ...            ...                  ...  ..        ...        ...    ...
# 1569087        NaN                  NaN  kg        NaN        NaN      N
# 1569088        NaN                  NaN  kg        NaN        NaN      N
# 1569089        NaN                  NaN  kg        NaN        NaN      N
# 1569090        NaN                  NaN  kg        NaN        NaN      N
# 1569091        NaN                  NaN  kg        NaN        NaN      N
#
#         incremntal  ic_capital  ic_other   payback bptool     sic     naics  \
# 154              N         NaN   25000.0  0.013816    NaN  2911.0  324110.0
# 155              N     47000.0  202000.0  1.870774    NaN  2911.0  324110.0
# 159              N         NaN       NaN  0.163488    NaN  2819.0       NaN
# 270              N         NaN   25000.0  0.013816    NaN  2911.0  324110.0
# 271              N     47000.0  202000.0  1.870774    NaN  2911.0  324110.0
# ...            ...         ...       ...       ...    ...     ...       ...
# 1569087          N         NaN       NaN       NaN    NaN  2051.0       NaN
# 1569088          N         NaN       NaN       NaN    NaN  2051.0       NaN
# 1569089          N         NaN       NaN       NaN    NaN  2051.0       NaN
# 1569090          N         NaN       NaN       NaN    NaN  2051.0       NaN
# 1569091          N         NaN       NaN       NaN    NaN  2051.0       NaN
#
#                 sales  employees  plant_area  \
# 154      1.200000e+09      325.0         NaN
# 155      1.200000e+09      325.0         NaN
# 159      1.800000e+07       98.0         NaN
# 270      1.200000e+09      325.0         NaN
# 271      1.200000e+09      325.0         NaN
# ...               ...        ...         ...
# 1569087  2.000000e+07      290.0    107127.0
# 1569088  2.000000e+07      290.0    107127.0
# 1569089  2.000000e+07      290.0    107127.0
# 1569090  2.000000e+07      290.0    107127.0
# 1569091  2.000000e+07      290.0    107127.0
#
#                                                   products  produnits  \
# 154                     Refined petroleum products, sulfur        4.0
# 155                     Refined petroleum products, sulfur        4.0
# 159                     hydrogen peroxide and butyllithium        2.0
# 270                     Refined petroleum products, sulfur        4.0
# 271                     Refined petroleum products, sulfur        4.0
# ...                                                    ...        ...
# 1569087  Sliced bread, hotdog and hamburger buns and co...        2.0
# 1569088  Sliced bread, hotdog and hamburger buns and co...        2.0
# 1569089  Sliced bread, hotdog and hamburger buns and co...        2.0
# 1569090  Sliced bread, hotdog and hamburger buns and co...        2.0
# 1569091  Sliced bread, hotdog and hamburger buns and co...        2.0
#
#           prodlevel  prodhours  numars  ec_plant_cost  ec_plant_usage  \
# 154      42000000.0     8760.0    14.0      2512297.0      41194817.0
# 155      42000000.0     8760.0    14.0      2512297.0      41194817.0
# 159      82000000.0     8568.0     6.0      1339944.0      34665006.0
# 270      42000000.0     8760.0    14.0      2512297.0      41194817.0
# 271      42000000.0     8760.0    14.0      2512297.0      41194817.0
# ...             ...        ...     ...            ...             ...
# 1569087  40000000.0     8760.0     4.0       338229.0      11826788.0
# 1569088  40000000.0     8760.0     4.0       338229.0      11826788.0
# 1569089  40000000.0     8760.0     4.0       338229.0      11826788.0
# 1569090  40000000.0     8760.0     4.0       338229.0      11826788.0
# 1569091  40000000.0     8760.0     4.0       338229.0      11826788.0
#
#          ec_emissions u.1  ed_plant_cost  ed_plant_usage  ef_plant_cost  \
# 154      2.760341e+07  kg            NaN             NaN            NaN
# 155      2.760341e+07  kg            NaN             NaN            NaN
# 159      2.626726e+07  kg            NaN             NaN            NaN
# 270      3.553132e+04  kg            NaN             NaN            NaN
# 271      3.553132e+04  kg            NaN             NaN            NaN
# ...               ...  ..            ...             ...            ...
# 1569087  2.733088e+04  kg       262684.0         19402.0         1560.0
# 1569088  2.733088e+04  kg       262684.0         19402.0         1560.0
# 1569089  2.733088e+04  kg       262684.0         19402.0         1560.0
# 1569090  2.733088e+04  kg       262684.0         19402.0         1560.0
# 1569091  2.733088e+04  kg       262684.0         19402.0         1560.0
#
#          e2_plant_cost  e2_plant_usage  e3_plant_cost  e3_plant_usage  \
# 154         43870282.0      10982620.0            NaN             NaN
# 155         43870282.0      10982620.0            NaN             NaN
# 159                NaN             NaN            NaN             NaN
# 270         43870282.0      10982620.0            NaN             NaN
# 271         43870282.0      10982620.0            NaN             NaN
# ...                ...             ...            ...             ...
# 1569087       412357.0         87570.0            NaN             NaN
# 1569088       412357.0         87570.0            NaN             NaN
# 1569089       412357.0         87570.0            NaN             NaN
# 1569090       412357.0         87570.0            NaN             NaN
# 1569091       412357.0         87570.0            NaN             NaN
#
#          e4_plant_cost  e4_plant_usage  e5_plant_cost  e5_plant_usage  \
# 154                NaN             NaN            NaN             NaN
# 155                NaN             NaN            NaN             NaN
# 159                NaN             NaN            NaN             NaN
# 270                NaN             NaN            NaN             NaN
# 271                NaN             NaN            NaN             NaN
# ...                ...             ...            ...             ...
# 1569087            NaN             NaN            NaN             NaN
# 1569088            NaN             NaN            NaN             NaN
# 1569089            NaN             NaN            NaN             NaN
# 1569090            NaN             NaN            NaN             NaN
# 1569091            NaN             NaN            NaN             NaN
#
#          e6_plant_cost  e6_plant_usage  e7_plant_cost  e7_plant_usage  \
# 154                NaN             NaN            NaN             NaN
# 155                NaN             NaN            NaN             NaN
# 159                NaN             NaN            NaN             NaN
# 270                NaN             NaN            NaN             NaN
# 271                NaN             NaN            NaN             NaN
# ...                ...             ...            ...             ...
# 1569087            NaN             NaN            NaN             NaN
# 1569088            NaN             NaN            NaN             NaN
# 1569089            NaN             NaN            NaN             NaN
# 1569090            NaN             NaN            NaN             NaN
# 1569091            NaN             NaN            NaN             NaN
#
#          e8_plant_cost  e8_plant_usage  e9_plant_cost  e9_plant_usage  \
# 154                NaN             NaN            NaN             NaN
# 155                NaN             NaN            NaN             NaN
# 159                NaN             NaN            NaN             NaN
# 270                NaN             NaN            NaN             NaN
# 271                NaN             NaN            NaN             NaN
# ...                ...             ...            ...             ...
# 1569087            NaN             NaN            NaN             NaN
# 1569088            NaN             NaN            NaN             NaN
# 1569089            NaN             NaN            NaN             NaN
# 1569090            NaN             NaN            NaN             NaN
# 1569091            NaN             NaN            NaN             NaN
#
#          e10_plant_cost  e10_plant_usage  e11_plant_cost  e11_plant_usage  \
# 154                 NaN              NaN             NaN              NaN
# 155                 NaN              NaN             NaN              NaN
# 159                 NaN              NaN             NaN              NaN
# 270                 NaN              NaN             NaN              NaN
# 271                 NaN              NaN             NaN              NaN
# ...                 ...              ...             ...              ...
# 1569087             NaN              NaN             NaN              NaN
# 1569088             NaN              NaN             NaN              NaN
# 1569089             NaN              NaN             NaN              NaN
# 1569090             NaN              NaN             NaN              NaN
# 1569091             NaN              NaN             NaN              NaN
#
#          e12_plant_cost  e12_plant_usage  w0_plant_cost  w0_plant_usage  \
# 154                 NaN              NaN            NaN             NaN
# 155                 NaN              NaN            NaN             NaN
# 159            827587.0         272410.0            NaN             NaN
# 270                 NaN              NaN            NaN             NaN
# 271                 NaN              NaN            NaN             NaN
# ...                 ...              ...            ...             ...
# 1569087             NaN              NaN            NaN             NaN
# 1569088             NaN              NaN            NaN             NaN
# 1569089             NaN              NaN            NaN             NaN
# 1569090             NaN              NaN            NaN             NaN
# 1569091             NaN              NaN            NaN             NaN
#
#          w1_plant_cost  w1_plant_usage  w2_plant_cost  w2_plant_usage  \
# 154           440329.0     890152000.0            NaN             NaN
# 155           440329.0     890152000.0            NaN             NaN
# 159                NaN             NaN            NaN             NaN
# 270           440329.0     890152000.0            NaN             NaN
# 271           440329.0     890152000.0            NaN             NaN
# ...                ...             ...            ...             ...
# 1569087            NaN             NaN          570.0           110.0
# 1569088            NaN             NaN          570.0           110.0
# 1569089            NaN             NaN          570.0           110.0
# 1569090            NaN             NaN          570.0           110.0
# 1569091            NaN             NaN          570.0           110.0
#
#          w3_plant_cost  w3_plant_usage  w4_plant_cost  w4_plant_usage  \
# 154                NaN             NaN            NaN             NaN
# 155                NaN             NaN            NaN             NaN
# 159                NaN             NaN            NaN             NaN
# 270                NaN             NaN            NaN             NaN
# 271                NaN             NaN            NaN             NaN
# ...                ...             ...            ...             ...
# 1569087            NaN             NaN       141174.0        983630.0
# 1569088            NaN             NaN       141174.0        983630.0
# 1569089            NaN             NaN       141174.0        983630.0
# 1569090            NaN             NaN       141174.0        983630.0
# 1569091            NaN             NaN       141174.0        983630.0
#
#          w5_plant_cost  w5_plant_usage  w6_plant_cost  w6_plant_usage  \
# 154                NaN             NaN            NaN             NaN
# 155                NaN             NaN            NaN             NaN
# 159                NaN             NaN            NaN             NaN
# 270                NaN             NaN            NaN             NaN
# 271                NaN             NaN            NaN             NaN
# ...                ...             ...            ...             ...
# 1569087            NaN             NaN            NaN             NaN
# 1569088            NaN             NaN            NaN             NaN
# 1569089            NaN             NaN            NaN             NaN
# 1569090            NaN             NaN            NaN             NaN
# 1569091            NaN             NaN            NaN             NaN
#
#         fuel_description
# 154                  NaN
# 155                  NaN
# 159                  NaN
# 270                  NaN
# 271                  NaN
# ...                  ...
# 1569087              NaN
# 1569088              NaN
# 1569089              NaN
# 1569090              NaN
# 1569091              NaN
#
# [104664 rows x 86 columns]
